# %%
q1 = """Given an integer array Arr of size N, find the count of elements whose value is
greater than all of its prior elements.

The first element is always included in the count.

Example:
Arr = [7,4,8,2,9]
Output = 3
Explanation: 7, 8, and 9 are greater than all previous elements.
"""

# %%
q2 = """A vendor sells N coloured balloons represented by array B.
Find the colour that appears an odd number of times.

If multiple colours have odd frequency, return the first such colour in the array.
If all colours occur even number of times, print 'All are even'.

Example:
Input: [r,g,b,b,g,y,y]
Output: r
"""

# %%
q4 = """There are n monkeys on a tree. Travelers offer bananas and peanuts.

Each monkey can eat k bananas or j peanuts.
Travelers provide m bananas and p peanuts.

Monkeys come down one at a time to eat. After eating they do not return to the tree.

If the last monkey gets less than k bananas or j peanuts, it eats whatever remains.

Input: n, m, p, k, j
Return the number of monkeys left on the tree.
"""

# %%
q5 = """Airport security confiscated items and stored them in an array.
Each item has a risk level: 0, 1, or 2.

Sort the array based on risk severity.

Example:
Input: [1,0,2,0,1,0,2]
Output: [0,0,0,1,1,2,2]
"""

# %%
q6 = """You are given three integers p, q, and r.

In one operation:
- Add 1 to any two numbers
- Subtract 1 from the third number

Find the minimum number of operations required to make p, q, and r equal.
If it is impossible, return -1.
"""

# %%
q7 = """Given an integer N, find the sum of the first N prime numbers.

A prime number is a number greater than 1 with no divisors except 1 and itself.
Example:
Input: 5
Output: 28
Explanation: 2 + 3 + 5 + 7 + 11 = 28
"""

# %%
q8 = """Given a weighted graph with n vertices and m edges,
find the shortest path between two specified vertices.

Input:
First line: n m
Next m lines: u v w (edge with weight)
Last line: source destination

Output:
Print the shortest path and total distance.
"""

# %%
q9 = """Write a program to manage expenses from a given total income.

Input:
Total income
Then repeatedly take:
Category (string)
Expense (integer)
until the user enters 'done'.

Output:
Print total income
Print total expenses
Print savings (income - expenses)
Print expense breakdown by category.
"""

# %%
q10 = """Given a string, determine:
1. The first non-repeating character
2. The most repeated character

Rules:
If input string is empty → print 'Invalid Input'
If all characters repeat → print 'None' followed by first repeating character.
If multiple characters have highest frequency, print the first non-repeating first, then the repeating one.
"""

# %%
q11 = """You are given:
N = length of array NUM
X = lower bound
Y = upper bound

Form pairs (NUM[i], NUM[j]).
Concatenate the two numbers (e.g., 5 and 5 → 55).

Check if:
X <= concatenated_number <= Y

Count how many such valid pairs exist.
"""

# %%
q12 = """Given two integers n1 and n2.

Find the n1-th prime number and n2-th prime number.
Multiply them and subtract 1.

Example:
Input: 4 5
Primes: 2,3,5,7,11
Output: 76
"""

# %%
q13 = """Read a string and remove all consecutive duplicate characters
while maintaining the original order.

Example:
Input: 223334566777
Output: 234567
"""

# %%
q14 = """Given an array of integers and a target sum h,
determine whether any subset of the array sums to h.

If such a subset exists → print 'Yes'
Otherwise → print 'No'

Example:
Array: [3,5,7,2]
Target: 10
Output: Yes (3 + 7 = 10)
"""
