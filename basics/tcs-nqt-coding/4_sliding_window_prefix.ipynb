# %%
"""
QUESTION: Golden House Manager Puzzle

There are N rooms containing coins.

You can enter a room and move only to the next room.

Find the starting and ending room indices such that
the sum of coins in the continuous rooms equals exactly K.

If multiple solutions exist return the one with the smallest start index.
"""
# Out:
# '\nQUESTION: Golden House Manager Puzzle\n\nThere are N rooms containing coins.\n\nYou can enter a room and move only to the next room.\n\nFind the starting and ending room indices such that\nthe sum of coins in the continuous rooms equals exactly K.\n\nIf multiple solutions exist return the one with the smallest start index.\n'

# %%
"""
QUESTION: Horse Betting Strategy

There are N horses with different betting prices.

Bob wants to bet on a continuous sequence of horses.

Total bet must be strictly less than K.

Find the maximum length of such a sequence.
"""
# Out:
# '\nQUESTION: Horse Betting Strategy\n\nThere are N horses with different betting prices.\n\nBob wants to bet on a continuous sequence of horses.\n\nTotal bet must be strictly less than K.\n\nFind the maximum length of such a sequence.\n'

# %%
"""
QUESTION: Maximum Sum k x k Submatrix

Given an M × N matrix and integer k.

Find the k × k submatrix with maximum sum.
"""
# Out:
# '\nQUESTION: Maximum Sum k x k Submatrix\n\nGiven an M × N matrix and integer k.\n\nFind the k × k submatrix with maximum sum.\n'
