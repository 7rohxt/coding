# %%
"""
QUESTION: String Conversion Operations

Given two strings A and B.

Choose a subset of characters from A.
Replace all characters in the subset with the smallest character
present in that subset.

Find the minimum operations required to convert A to B.
"""
# Out:
# '\nQUESTION: String Conversion Operations\n\nGiven two strings A and B.\n\nChoose a subset of characters from A.\nReplace all characters in the subset with the smallest character\npresent in that subset.\n\nFind the minimum operations required to convert A to B.\n'

# %%
"""
QUESTION: Balance * and # in String

Given a string containing '*' and '#'.

Return:
positive number if '*' > '#'
negative number if '#' > '*'
0 if both are equal.
"""
# Out:
# "\nQUESTION: Balance * and # in String\n\nGiven a string containing '*' and '#'.\n\nReturn:\npositive number if '*' > '#'\nnegative number if '#' > '*'\n0 if both are equal.\n"

# %%
"""
QUESTION: String Transformation

Input three words.

1st word → replace vowels with %
2nd word → replace consonants with #
3rd word → convert to uppercase

Concatenate all three results.
"""
# Out:
# '\nQUESTION: String Transformation\n\nInput three words.\n\n1st word → replace vowels with %\n2nd word → replace consonants with #\n3rd word → convert to uppercase\n\nConcatenate all three results.\n'

# %%
"""
QUESTION: Count Common Subsequences in Two Strings

Given two strings find the number of subsequences
that are common in both strings.
"""
# Out:
# '\nQUESTION: Count Common Subsequences in Two Strings\n\nGiven two strings find the number of subsequences\nthat are common in both strings.\n'
