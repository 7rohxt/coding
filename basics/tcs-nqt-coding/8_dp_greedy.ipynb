# %%
"""
QUESTION: House Robber Problem

There are N houses each with some value.

A thief cannot steal from two adjacent houses.

Find the maximum value that can be stolen.
"""

# %%
"""
QUESTION: Collecting Candies

There are N boxes of candies.

You can combine two boxes at a time.
Combining boxes with X and Y candies costs X+Y seconds.

Find the minimum total time required to combine all boxes.
"""

# %%
"""
QUESTION: Two Wheeler Four Wheeler Production

Total vehicles = V
Total wheels = W

Two-wheelers have 2 wheels.
Four-wheelers have 4 wheels.

Determine how many of each were produced.
"""

# %%
"""
QUESTION: Monkeys and Food

N monkeys sit on a tree.

Each monkey eats either:
k bananas OR j peanuts.

Given total bananas m and peanuts p,
determine how many monkeys remain on the tree.
"""
