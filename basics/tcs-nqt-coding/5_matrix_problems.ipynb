# %%
"""
QUESTION: Row With Maximum 1s

A parking lot is represented by an R × C matrix.

0 = empty space
1 = occupied space

Return the row index with the maximum number of occupied spaces.
"""
# Out:
# '\nQUESTION: Row With Maximum 1s\n\nA parking lot is represented by an R × C matrix.\n\n0 = empty space\n1 = occupied space\n\nReturn the row index with the maximum number of occupied spaces.\n'

# %%
"""
QUESTION: Maximum Size Square Submatrix with All 1s

Given a binary matrix find the largest square submatrix
that contains only 1s.
"""
# Out:
# '\nQUESTION: Maximum Size Square Submatrix with All 1s\n\nGiven a binary matrix find the largest square submatrix\nthat contains only 1s.\n'
