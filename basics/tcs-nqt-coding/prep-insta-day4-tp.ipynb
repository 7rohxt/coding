# %% [markdown]
# ## Two Pointers / Sliding Window (Day 4)
#
# 1. Two Sum in a Sorted Array | Input: nums = [2, 7, 11, 15], target = 9
#
# 2. Container With Most Water | Input: height = [1,8,6,2,5,4,8,3,7]
#
# 3. Remove Duplicates from Sorted Array | Input: nums = [1,1,2,2,3,3,4]
