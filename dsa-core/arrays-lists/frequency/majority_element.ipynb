# %% [markdown]
# ### Problem: Majority Element
#
# #### Problem Statement
# You are given an array of integers `nums`.
#
# Return the **element that appears more than ⌊n / 2⌋ times**, where `n` is the length of the array.
# If **no such element exists**, return `-1`.
#
# The majority element is guaranteed to appear **more than half** of the time if it exists.
#
# ---
#
# #### Input
# - `nums`: a list of integers
#
# #### Output
# - An integer representing the majority element
# - Return `-1` if no majority element exists
#
# ---
#
# #### Examples
#
# ```text
# Input:  [3, 2, 3]
# Output: 3

# %% [markdown]
# ### Initial Solution & Optimal

# %%
def majority_element (nums):
    freq = {}

    for num in nums:
        if num in freq:
            freq[num] += 1
        else:
            freq[num] = 1
    
    for num in freq:
        if freq[num] > len(nums)//2:
            return num
    return -1

# %%
nums = [3,2,3]
print(majority_element (nums))
# Out:
# 3
